# %% [markdown]
# #Variables?
#
#
# 1.   Variable names cannot start with numbers.
# 2.   Python keywords (reserved words - e.g., if, print, while, ) cannot be used as variable names.

# %%
x = 100 # type: number (int)
first_name = "Kevin" #type: text (string)
z = 2.5 # type: number (float)

# %%
#Print the content in the variable --> use the print function
print(x)
print(first_name)
print (z)
# Out:
# 100
# Kevin
# 2.5

# %%
wage = 400
print("Your daily wage is $ ", wage)
# Out:
# Your daily wage is $  400

# %%
weekly_wage = 2000
print("S", wage, "per day is $", weekly_wage, "per week")
# Out:
# S 400 per day is $ 2000 per week

# %%
print("Enter name of best friend", end = " ")
best_friend = input()
print("My best friend is", best_friend)
# Out:
# Enter name of best friend kevin
# My best friend is kevin

# %%
print("Enter wage:", end = " ")
#wage = int(input())
wage = int(input())

new_wage = wage + 10
print("New wage: ", new_wage)
# Out:
# Enter wage: 12
# New wage:  22
