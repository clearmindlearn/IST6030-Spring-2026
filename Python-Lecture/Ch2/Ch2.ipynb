# %% [markdown]
# # Variable & Assignments

# %%
x = 10 # variable_name = (assignment) Value  ---> variable x is created and 10 is stored inside the variable
       # (ref) variable x is refering to the object of class/type integer.

x = x + 10
x = x + 10

print(x)
# Out:
# 30

# %%
x = 10
y = 20
x = y + 10 + x
print (x)
# Out:
# 40

# %% [markdown]
# #Python Data Types
#
#
# *   Numeric type: int & float  --> immutable (cannot change or update)
# *   Text type: str (string)  -> immutable (cannot change or update)
# *   Sequence Type: list (mutable), tuple, range
# *   Mapping type: dict (mutable)

# %%
x = 10
#Object has 1. value 2. Type 3. Idenity

print(" x", x,  "type", type(x), "id", id(x))
# Out:
#  x 10 type <class 'int'> id 11654664

# %%
y = 3.14
#object of type/class float
print ("y", y, "type", type(y), "id", id(y))
# Out:
# y 3.14 type <class 'float'> id 133892181465520

# %%
#int/float is immutable
x = 10
x = 5
print (x)
# Out:
# 5

# %%
#String  --> immutable

first_name = "Kevin"
first_name = "Alice"

# %%
#String concaternation
first_name = "Kevin"
last_name = "Snow"
full_name = first_name + " " + last_name # + --> string concaternation

print(full_name)
# Out:
# Kevin Snow

# %%
#Section 2.5

x = 4
w = 2
y = 3*(x + 10/w)

y
# Out:
# 27.0

# %%
#2.6 challenge act 2.6.1

PI = 3.14
circle_radius = float (input())

# your code goes here
circle_circum = 2 * PI * circle_radius

print(f"Circle circum: {circle_circum:.2f}" )
# Out:
# 10
# Circle circum: 62.80

# %%
GRAVITY_CONST = 6.673e-11
EARTH_MASS = 5.98e+24

dist_center = float(input())

""" Your code goes here """
accel_gravity = (GRAVITY_CONST * EARTH_MASS) /dist_center**2

print(f"Gravity acceleration: {accel_gravity:.2f}")

# %%
# Section 2.7

print(20/10) #returns a floating point number

#floating division operator //
# used to round DOWN the result of a floating-point division
# to the closest smaller integer value
print (20//10)
print(5 // 2) #2.5 --> 2
print(5.0 // 2) #2.5  ->2.0


# Module (%) --> evaluate the remainder of the division
print(5%2)
print(70%7)
# Out:
# 2.0
# 2
# 2
# 2.0
# 1
# 0

# %%
# chall act 2.7.2 Division and modulo
total_volume = int(input())
purse_volume = int(input())

""" Your code goes here """
num_purses = total_volume // purse_volume

print("Maximum number of purses:", num_purses)
# Out:
# 100
# 33
# Maximum number of purses: 3

# %%
100/33
# Out:
# 3.0303030303030303

# %%
#Section 2.9

import math

z = 4.5
z = math.pow(math.floor(z), 2.0)
print (z)
# Out:
# 16.0

# %%
#Chall 2.9.3
import math

h = float(input())
i = float(input())

""" Your code goes here """
j = math.sqrt(h * i)

print(f"j = {j:.2f}")  # Outputs j with 2 decimal places
# Out:
# 3
# 5
# j = 3.87
